# %% [markdown]
# # Building and Implementing Machine Learning Models

# %% [markdown]
# ### Preparing dataset and Normalizing certain column data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import logging
import sys, os
import warnings
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt # data visualization

# %%
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from train import TrainModel
from file import FileHandler

# %%
file_handler= FileHandler()

# %%
df = file_handler.read_csv('../features/train_features.csv')

# %%
# Making a new data set for model building
trainS= df[['Store', 'DayOfWeek','Promo',
       'StateHoliday', 'SchoolHoliday','StoreType',
       'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
       'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
       'Promo2SinceYear']]
trainS.shape
# Out:
# (844392, 13)

# %%
# Out:
# (1017209, 15)

# %%
# Visualization to chech whether the data is distributed normally
trainS.hist(figsize=(25,25))
plt.show()

# %% [markdown]
# ##### Spliting the dataset

# %% [markdown]
# ##### Creating and Training the Model

# %%
model = RandomForestRegressor(n_jobs=-1, n_estimators=15,
                                verbose=True,
                                max_depth=15,
                                oob_score=True,
                                criterion='mse',
                                max_features='sqrt',
                                min_samples_split=2,
                                min_samples_leaf=1,
                                random_state=101)

train_model = TrainModel(model, "Random Forest Regressor")
train_model.train_sales()
train_model.train_customers()
# Out:
# 2022/05/31 09:30:10 WARNING mlflow.tracking.context.git_context: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh()
#
# All git commands will error until this is rectified.
#
# This initial warning can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|none|n|0: for no warning or exception
#     - warn|w|warning|1: for a printed warning
#     - error|e|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet
#
# 2022/05/31 09:30:10 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '58d252653a0849a4ad1b63a624aa659b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2022/05/31 09:30:12 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\ProgramData\Anaconda3\lib\site-packages\mlflow\utils\autologging_utils\safety.py:535: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel()."
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    6.6s finished
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.0s finished
# 2022/05/31 09:30:24 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\ProgramData\Anaconda3\lib\site-packages\mlflow\models\signature.py:129: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2022/05/31 09:30:38 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9ffbc924498949d69d36fc6dda60e052', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2022/05/31 09:30:40 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\ProgramData\Anaconda3\lib\site-packages\mlflow\utils\autologging_utils\safety.py:535: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel()."
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    5.6s finished
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.0s finished
# 2022/05/31 09:30:51 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\ProgramData\Anaconda3\lib\site-packages\mlflow\models\signature.py:129: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."

# %%
model = RandomForestRegressor(n_jobs=-1, n_estimators=15,
                                verbose=True,
                                max_depth=15,
                                min_samples_split=2,
                                min_samples_leaf=1)

train_model = TrainModel(model, "Random Forest Regressor")
train_model.train_sales()
train_model.train_customers()
# Out:
# 2022/05/30 19:59:22 WARNING mlflow.tracking.context.git_context: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh()
#
# All git commands will error until this is rectified.
#
# This initial warning can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|none|n|0: for no warning or exception
#     - warn|w|warning|1: for a printed warning
#     - error|e|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet
#
# 2022/05/30 19:59:23 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2f58a0d5b49f4e288a3a609deac81dd9', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2022/05/30 19:59:24 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\ProgramData\Anaconda3\lib\site-packages\mlflow\utils\autologging_utils\safety.py:535: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel()."
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   25.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.0s finished
# 2022/05/30 19:59:52 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\ProgramData\Anaconda3\lib\site-packages\mlflow\models\signature.py:129: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2022/05/30 20:00:03 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'eb693229bc7747c1a8736fae557b04fa', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2022/05/30 20:00:05 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\ProgramData\Anaconda3\lib\site-packages\mlflow\utils\autologging_utils\safety.py:535: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel()."
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   23.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  15 out of  15 | elapsed:    0.0s finished
# 2022/05/30 20:00:30 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\ProgramData\Anaconda3\lib\site-packages\mlflow\models\signature.py:129: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."

# %%
# Prediction
predict= model.predict(X_test)
predict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HEWANM~1\AppData\Local\Temp/ipykernel_23572/446948644.py in <module>
#       1 # Prediction
# ----> 2 predict= model.predict(X_test)
#       3 predict
#
# NameError: name 'X_test' is not defined
